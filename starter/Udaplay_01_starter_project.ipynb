# %% [markdown]
# # [STARTER] Udaplay Project

# %% [markdown]
# ## Part 01 - Offline RAG
#
# In this part of the project, you'll build your VectorDB using Chroma.
#
# The data is inside folder `project/starter/games`. Each file will become a document in the collection you'll create.
# Example.:
# ```json
# {
#   "Name": "Gran Turismo",
#   "Platform": "PlayStation 1",
#   "Genre": "Racing",
#   "Publisher": "Sony Computer Entertainment",
#   "Description": "A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.",
#   "YearOfRelease": 1997
# }
# ```

# %% [markdown]
# ### Setup

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
# !pip install chromadb
# !pip install openai
# !pip install pydantic
# !pip install python-dotenv
# !pip install tavily-python
# Out:
# Requirement already satisfied: chromadb in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (1.5.9)
# Requirement already satisfied: build>=1.0.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.48.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (2.4.6)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.26.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (1.80.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (36.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from build>=1.0.3->chromadb) (26.2)
# Requirement already satisfied: pyproject_hooks in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx>=0.27.0->chromadb) (4.13.0)
# Requirement already satisfied: certifi in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx>=0.27.0->chromadb) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx>=0.27.0->chromadb) (3.16)
# Requirement already satisfied: h11>=0.16 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.34.2)
# Requirement already satisfied: requests-oauthlib in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from kubernetes>=28.1.0->chromadb) (3.13.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb) (1.24.2)
# Requirement already satisfied: flatbuffers in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic>=2.0->chromadb) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from tokenizers>=0.13.2->chromadb) (1.16.4)
# Requirement already satisfied: click>=8.4.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.7)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: openai in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (2.38.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->openai) (3.16)
# Requirement already satisfied: certifi in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: pydantic in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (2.13.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from pydantic) (0.4.2)
# Requirement already satisfied: python-dotenv in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: tavily-python in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (0.7.24)
# Requirement already satisfied: requests in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from tavily-python) (2.34.2)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from tavily-python) (0.13.0)
# Requirement already satisfied: httpx in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: regex in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from tiktoken>=0.5.1->tavily-python) (2026.5.9)
# Requirement already satisfied: anyio in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx->tavily-python) (4.13.0)
# Requirement already satisfied: certifi in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx->tavily-python) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: idna in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpx->tavily-python) (3.16)
# Requirement already satisfied: h11>=0.16 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from requests->tavily-python) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/carlosvaleriano/Desktop/Upwork Portfolio/Udacity Portfolio/udaplay-project/.venv/lib/python3.14/site-packages (from requests->tavily-python) (2.7.0)

# %%
import os
import json
import chromadb
from chromadb.utils import embedding_functions
from dotenv import load_dotenv

# %%
# TODO: Create a .env file with the following variables
# OPENAI_API_KEY="YOUR_KEY"
# CHROMA_OPENAI_API_KEY="YOUR_KEY"
# TAVILY_API_KEY="YOUR_KEY"

# %%
# TODO: Load environment variables
load_dotenv()
assert os.getenv('OPENAI_API_KEY') is not None
assert os.getenv('TAVILY_API_KEY') is not None

# %% [markdown]
# ### VectorDB Instance

# %%
# Instantiate ChromaDB Client
chroma_client = chromadb.PersistentClient(path="chromadb")

# %% [markdown]
# ### Collection

# %%
# Pick one embedding function
# If picking something different than openai, 
# make sure you use the same when loading it
embedding_fn = embedding_functions.OpenAIEmbeddingFunction()

# %%
# Create a collection
# Choose any name you want
collection = chroma_client.get_or_create_collection(
    name="udaplay",
    embedding_function=embedding_fn
)

# %% [markdown]
# ### Add documents

# %%
# Make sure you have a directory "project/starter/games"
data_dir = "games"

for file_name in sorted(os.listdir(data_dir)):
    if not file_name.endswith(".json"):
        continue

    file_path = os.path.join(data_dir, file_name)
    with open(file_path, "r", encoding="utf-8") as f:
        game = json.load(f)

    # You can change what text you want to index
    content = f"[{game['Platform']}] {game['Name']} ({game['YearOfRelease']}) - {game['Description']}"

    # Use file name (like 001) as ID
    doc_id = os.path.splitext(file_name)[0]

    collection.add(
        ids=[doc_id],
        documents=[content],
        metadatas=[game]
    )

# %% [markdown]
# Query the Database

# %%
results = collection.query(
    query_texts=["A racing game on PlayStation"],
    n_results=2
)

# Print results of query
print(results["documents"])
# Out:
# [['[PlayStation 3] Gran Turismo 5 (2010) - A comprehensive racing simulator featuring a vast selection of vehicles and tracks, with realistic driving physics.', '[PlayStation 1] Gran Turismo (1997) - A realistic racing simulator featuring a wide array of cars and tracks, setting a new standard for the genre.']]
